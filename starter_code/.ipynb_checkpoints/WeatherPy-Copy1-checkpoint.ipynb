# coihaique
# saint-pierre
# ust-nera
# bealanana
# anyang
# goderich
# hoquiam
# zhigansk
# saryshagan
# rosetta
# roma
# gambiran
# yatou
# alekseyevsk
# dapaong
# muhos
# sulangan
# karasburg
# hamilton
# gwadar
# matiguas
# lumeje
# poum
# alofi
# tucumcari
# verkhnyaya maksakovka
# kahta
# california city
# anadyr
# grottammare
# shanting
# mehamn
# bure
# kedrovyy
# labutta
# chokwe
# gamba
# lixourion
# les cayes
# annamalainagar
# manggar
# bereda
# luderitz
# burgeo
# vardo
# zhaotong
# aasiaat
# halalo
# bilibino
# khandyga
# banda aceh
# bilma
# litoral del san juan
# el faiyum
# raton
# la ronge
# clonakilty
# segezha
# badami
# poronaysk
# barroso
# finschhafen
# fare
# mantua
# poso
# houma
# santiago del estero
# abadan
# zhangjiakou
# visby
# muravlenko
# kahului
# vihari
# tambul
# lasa
# mahadday weyne
# rio grande
# kochevo
# dingle
# belaya gora
# dumas
# puerto wilches
# samalaeulu
# tangping
# keelung
# pensilvania
# portmore
# malacacheta
# synya
# panjwin
# merauke
# zhangye
# malwan
# port augusta
# fonte boa
# zyryanka
# egvekinot
# sibenik
# kikwit
# heihe
# turukhansk
# tautira
# buchanan
# kitimat

# %%
#api.openweathermap.org/data/2.5/weather?q=Atlanta&appid=c1034ccd7af6a3b9dab48db651f430ce

# %%
print(weather_api_key)
# Out:
# c1034ccd7af6a3b9dab48db651f430ce

# %%
#initial code constructed and tested on one city
city = input("enter city name")
query_url = "http://api.openweathermap.org/data/2.5/weather?q=" + city + "&units=imperial" + "&appid=" + weather_api_key
print(query_url)
response = requests.get(query_url)
api_response = response.json()
formatted_response = json.dumps(api_response,indent = 4)
print(formatted_response)
# Out:
# enter city nameLondon
# http://api.openweathermap.org/data/2.5/weather?q=London&units=imperial&appid=c1034ccd7af6a3b9dab48db651f430ce
# {
#     "coord": {
#         "lon": -0.1257,
#         "lat": 51.5085
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 48.76,
#         "feels_like": 44.01,
#         "temp_min": 47.3,
#         "temp_max": 50.56,
#         "pressure": 1008,
#         "humidity": 85
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 11.5,
#         "deg": 230
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1643948754,
#     "sys": {
#         "type": 2,
#         "id": 2019646,
#         "country": "GB",
#         "sunrise": 1643960063,
#         "sunset": 1643993664
#     },
#     "timezone": 0,
#     "id": 2643743,
#     "name": "London",
#     "cod": 200
# }

# %%
#defining the function to process the response from weather api and return only values needed
def process_response(api_response):
    coord_key = api_response['coord']
    lon = coord_key['lon']
    lat = coord_key['lat']
    main_key = api_response['main']
    temp_max = main_key['temp_max']
    humidity = main_key['humidity']
    wind_key = api_response['wind']
    speed = wind_key['speed']
    clouds_key = api_response['clouds']
    cloudiness = clouds_key ['all']
    sys_key = api_response['sys']
    country = sys_key['country']
    dt = api_response['dt']
    return(city,lat,lon,round(temp_max,2),humidity,cloudiness,round(speed,2),country,dt)

# %%
#part of debugging process
coord_key = api_response['coord']
coord_key
lon = coord_key['lon']
lat = coord_key['lat']
print(lon,lat)
main_key = api_response['main']
main_key 
temp_max = main_key['temp_max']
humidity = main_key['humidity']
print(temp_max,humidity)
wind_key = api_response['wind']
wind_key
speed = wind_key['speed']
speed
clouds_key = api_response['clouds']
clouds_key
cloudiness = clouds_key ['all']
sys_key = api_response['sys']
country = sys_key['country']
dt = api_response['dt']
# Out:
# -0.1257 51.5085
# 50.56 85

# %%
#Debugging.  testing one city.
process_response(api_response)
# Out:
# ('London', 51.5085, -0.1257, 50.56, 85, 100, 11.5, 'GB', 1643948754)

# %%
#Made to process all cities
max_num = 525
city_num = 0
processed = 0
current_set = 1
current_record = 1
data = []

# time.sleep(60)
# City not found. Skipping...
# Processing Record 28 of Set 1 | kota bahru

while city_num < max_num:
    city = cities[processed]
    query_url = "http://api.openweathermap.org/data/2.5/weather?q=" + city + "&units=imperial" + "&appid=" + weather_api_key
    response = requests.get(query_url)
    api_response = response.json()
    processed = processed + 1

    output_text = "Processing Record " + str(current_record) + " of Set " + str(current_set) + " | " + city
    print(output_text)
    #print(api_response['cod'])
    if api_response['cod'] == '404':
        print("City not found.  Skipping...") 
    else:    
        this_row = process_response(api_response)
        city_num = city_num + 1
        data.append(this_row)
        #print(this_row)

    current_record = current_record + 1
    if processed % 50 == 0:
        time.sleep(60)
        current_set = current_set + 1
        current_record = 1
        
#print(data)
# Out:
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found.  Skipping...
# Processing Record 3 of Set 1 | caronport
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | olafsvik
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | talnakh
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | esso
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | deputatskiy
# Processing Record 12 of Set 1 | bethel
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | flinders
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | datong
# Processing Record 18 of Set 1 | tasiilaq
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | chicama
# Processing Record 22 of Set 1 | chuy
# Processing Record 23 of Set 1 | luga
# Processing Record 24 of Set 1 | taolanaro
# City not found.  Skipping...
# Processing Record 25 of Set 1 | bengkulu
# Processing Record 26 of Set 1 | karratha
# Processing Record 27 of Set 1 | paoua
# Processing Record 28 of Set 1 | longyearbyen
# Processing Record 29 of Set 1 | chokurdakh
# Processing Record 30 of Set 1 | moron
# Processing Record 31 of Set 1 | aswan
# Processing Record 32 of Set 1 | provideniya
# Processing Record 33 of Set 1 | kruisfontein
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | ilembo
# Processing Record 37 of Set 1 | arraial do cabo
# Processing Record 38 of Set 1 | katsuura
# Processing Record 39 of Set 1 | calabozo
# Processing Record 40 of Set 1 | nanzhang
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | hambantota
# Processing Record 43 of Set 1 | mar del plata
# Processing Record 44 of Set 1 | sisimiut
# Processing Record 45 of Set 1 | kudahuvadhoo
# Processing Record 46 of Set 1 | bambous virieux
# Processing Record 47 of Set 1 | coquimbo
# Processing Record 48 of Set 1 | dunedin
# Processing Record 49 of Set 1 | port keats
# Processing Record 50 of Set 1 | mbandaka
# Processing Record 1 of Set 2 | salalah
# Processing Record 2 of Set 2 | saint-francois
# Processing Record 3 of Set 2 | kaeo
# Processing Record 4 of Set 2 | opuwo
# Processing Record 5 of Set 2 | padang
# Processing Record 6 of Set 2 | kaitangata
# Processing Record 7 of Set 2 | nikolskoye
# Processing Record 8 of Set 2 | samusu
# City not found.  Skipping...
# Processing Record 9 of Set 2 | severo-kurilsk
# Processing Record 10 of Set 2 | faanui
# Processing Record 11 of Set 2 | broome
# Processing Record 12 of Set 2 | yar-sale
# Processing Record 13 of Set 2 | khatanga
# Processing Record 14 of Set 2 | dikson
# Processing Record 15 of Set 2 | barentsburg
# City not found.  Skipping...
# Processing Record 16 of Set 2 | gondanglegi
# Processing Record 17 of Set 2 | upernavik
# Processing Record 18 of Set 2 | saint-philippe
# Processing Record 19 of Set 2 | hasaki
# Processing Record 20 of Set 2 | norman wells
# Processing Record 21 of Set 2 | eldorado
# Processing Record 22 of Set 2 | airai
# Processing Record 23 of Set 2 | vao
# Processing Record 24 of Set 2 | geraldton
# Processing Record 25 of Set 2 | klaksvik
# Processing Record 26 of Set 2 | nemuro
# Processing Record 27 of Set 2 | necochea
# Processing Record 28 of Set 2 | glenwood springs
# Processing Record 29 of Set 2 | palabuhanratu
# City not found.  Skipping...
# Processing Record 30 of Set 2 | bluff
# Processing Record 31 of Set 2 | tolga
# Processing Record 32 of Set 2 | belushya guba
# City not found.  Skipping...
# Processing Record 33 of Set 2 | bathsheba
# Processing Record 34 of Set 2 | cabo san lucas
# Processing Record 35 of Set 2 | butaritari
# Processing Record 36 of Set 2 | saleaula
# City not found.  Skipping...
# Processing Record 37 of Set 2 | lebu
# Processing Record 38 of Set 2 | albania
# Processing Record 39 of Set 2 | maniitsoq
# Processing Record 40 of Set 2 | tuktoyaktuk
# Processing Record 41 of Set 2 | seoul
# Processing Record 42 of Set 2 | avarua
# Processing Record 43 of Set 2 | kopaganj
# Processing Record 44 of Set 2 | clyde river
# Processing Record 45 of Set 2 | pisco
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | torbay
# Processing Record 48 of Set 2 | lilongwe
# Processing Record 49 of Set 2 | grand-santi
# Processing Record 50 of Set 2 | verkhnyaya inta
# Processing Record 1 of Set 3 | jaguariaiva
# Processing Record 2 of Set 3 | zhanatas
# City not found.  Skipping...
# Processing Record 3 of Set 3 | luanda
# Processing Record 4 of Set 3 | tuensang
# Processing Record 5 of Set 3 | puerto ayora
# Processing Record 6 of Set 3 | port blair
# Processing Record 7 of Set 3 | gorontalo
# Processing Record 8 of Set 3 | gat
# Processing Record 9 of Set 3 | qaanaaq
# Processing Record 10 of Set 3 | victoria
# Processing Record 11 of Set 3 | rimbey
# Processing Record 12 of Set 3 | tuatapere
# Processing Record 13 of Set 3 | bud
# Processing Record 14 of Set 3 | thompson
# Processing Record 15 of Set 3 | asau
# Processing Record 16 of Set 3 | saskylakh
# Processing Record 17 of Set 3 | leningradskiy
# Processing Record 18 of Set 3 | cape town
# Processing Record 19 of Set 3 | kapaa
# Processing Record 20 of Set 3 | rungata
# City not found.  Skipping...
# Processing Record 21 of Set 3 | mackenzie
# Processing Record 22 of Set 3 | te anau
# Processing Record 23 of Set 3 | port lincoln
# Processing Record 24 of Set 3 | taga dzong
# City not found.  Skipping...
# Processing Record 25 of Set 3 | conde
# Processing Record 26 of Set 3 | simpang empat
# Processing Record 27 of Set 3 | bondo
# Processing Record 28 of Set 3 | tamworth
# Processing Record 29 of Set 3 | linguere
# Processing Record 30 of Set 3 | hervey bay
# Processing Record 31 of Set 3 | vostok
# Processing Record 32 of Set 3 | yellowknife
# Processing Record 33 of Set 3 | saldanha
# Processing Record 34 of Set 3 | port alfred
# Processing Record 35 of Set 3 | port elizabeth
# Processing Record 36 of Set 3 | antofagasta
# Processing Record 37 of Set 3 | carnarvon
# Processing Record 38 of Set 3 | mahebourg
# Processing Record 39 of Set 3 | beloha
# Processing Record 40 of Set 3 | lengshuijiang
# Processing Record 41 of Set 3 | walvis bay
# Processing Record 42 of Set 3 | atuona
# Processing Record 43 of Set 3 | pangody
# Processing Record 44 of Set 3 | kondinskoye
# Processing Record 45 of Set 3 | atar
# Processing Record 46 of Set 3 | san patricio
# Processing Record 47 of Set 3 | nome
# Processing Record 48 of Set 3 | moindou
# Processing Record 49 of Set 3 | amderma
# City not found.  Skipping...
# Processing Record 50 of Set 3 | evanston
# Processing Record 1 of Set 4 | langres
# Processing Record 2 of Set 4 | hilo
# Processing Record 3 of Set 4 | buraydah
# Processing Record 4 of Set 4 | nizhneyansk
# City not found.  Skipping...
# Processing Record 5 of Set 4 | nuuk
# Processing Record 6 of Set 4 | sakakah
# Processing Record 7 of Set 4 | jeremie
# Processing Record 8 of Set 4 | zhezkazgan
# Processing Record 9 of Set 4 | bontang
# Processing Record 10 of Set 4 | kodinsk
# Processing Record 11 of Set 4 | roanne
# Processing Record 12 of Set 4 | barrow
# Processing Record 13 of Set 4 | songjianghe
# Processing Record 14 of Set 4 | naze
# Processing Record 15 of Set 4 | kerki
# City not found.  Skipping...
# Processing Record 16 of Set 4 | mastic beach
# Processing Record 17 of Set 4 | abha
# Processing Record 18 of Set 4 | helong
# Processing Record 19 of Set 4 | takoradi
# Processing Record 20 of Set 4 | kiruna
# Processing Record 21 of Set 4 | panaba
# Processing Record 22 of Set 4 | ribeira grande
# Processing Record 23 of Set 4 | lunavada
# Processing Record 24 of Set 4 | lolua
# City not found.  Skipping...
# Processing Record 25 of Set 4 | itarema
# Processing Record 26 of Set 4 | crailsheim
# Processing Record 27 of Set 4 | pailitas
# Processing Record 28 of Set 4 | shirokiy
# Processing Record 29 of Set 4 | quatre cocos
# Processing Record 30 of Set 4 | olga
# Processing Record 31 of Set 4 | vinh long
# Processing Record 32 of Set 4 | norden
# Processing Record 33 of Set 4 | ginir
# Processing Record 34 of Set 4 | athabasca
# Processing Record 35 of Set 4 | kamenka
# Processing Record 36 of Set 4 | santa lucia
# Processing Record 37 of Set 4 | tiksi
# Processing Record 38 of Set 4 | pundaguitan
# Processing Record 39 of Set 4 | batticaloa
# Processing Record 40 of Set 4 | zmiyiv
# Processing Record 41 of Set 4 | naryan-mar
# Processing Record 42 of Set 4 | berdigestyakh
# Processing Record 43 of Set 4 | blagoyevo
# Processing Record 44 of Set 4 | liepaja
# Processing Record 45 of Set 4 | ola
# Processing Record 46 of Set 4 | hay river
# Processing Record 47 of Set 4 | salinas
# Processing Record 48 of Set 4 | tagusao
# Processing Record 49 of Set 4 | zapolyarnyy
# Processing Record 50 of Set 4 | narsaq
# Processing Record 1 of Set 5 | hefei
# Processing Record 2 of Set 5 | zaraza
# Processing Record 3 of Set 5 | college
# Processing Record 4 of Set 5 | bayeux
# Processing Record 5 of Set 5 | sitka
# Processing Record 6 of Set 5 | umm lajj
# Processing Record 7 of Set 5 | tutoia
# Processing Record 8 of Set 5 | nyzhnya duvanka
# Processing Record 9 of Set 5 | kulachi
# Processing Record 10 of Set 5 | sinop
# Processing Record 11 of Set 5 | rawson
# Processing Record 12 of Set 5 | savelugu
# Processing Record 13 of Set 5 | tumannyy
# City not found.  Skipping...
# Processing Record 14 of Set 5 | houston
# Processing Record 15 of Set 5 | sao joao da barra
# Processing Record 16 of Set 5 | ruwi
# Processing Record 17 of Set 5 | naples
# Processing Record 18 of Set 5 | shimoda
# Processing Record 19 of Set 5 | vaitupu
# City not found.  Skipping...
# Processing Record 20 of Set 5 | isangel
# Processing Record 21 of Set 5 | tubuala
# Processing Record 22 of Set 5 | tsihombe
# City not found.  Skipping...
# Processing Record 23 of Set 5 | los llanos de aridane
# Processing Record 24 of Set 5 | beringovskiy
# Processing Record 25 of Set 5 | santa cruz cabralia
# Processing Record 26 of Set 5 | souillac
# Processing Record 27 of Set 5 | ostrovnoy
# Processing Record 28 of Set 5 | coahuayana
# Processing Record 29 of Set 5 | macapa
# Processing Record 30 of Set 5 | pitimbu
# Processing Record 31 of Set 5 | krasnoselkup
# Processing Record 32 of Set 5 | ilulissat
# Processing Record 33 of Set 5 | acarau
# Processing Record 34 of Set 5 | kenora
# Processing Record 35 of Set 5 | krutikha
# Processing Record 36 of Set 5 | pasadena
# Processing Record 37 of Set 5 | paracuru
# Processing Record 38 of Set 5 | hualmay
# Processing Record 39 of Set 5 | pudozh
# Processing Record 40 of Set 5 | ballina
# Processing Record 41 of Set 5 | namibe
# Processing Record 42 of Set 5 | esperance
# Processing Record 43 of Set 5 | puerto asis
# Processing Record 44 of Set 5 | portoferraio
# Processing Record 45 of Set 5 | faya
# Processing Record 46 of Set 5 | marcona
# City not found.  Skipping...
# Processing Record 47 of Set 5 | mount isa
# Processing Record 48 of Set 5 | grand gaube
# Processing Record 49 of Set 5 | los alamos
# Processing Record 50 of Set 5 | jadu
# Processing Record 1 of Set 6 | cayenne
# Processing Record 2 of Set 6 | lompoc
# Processing Record 3 of Set 6 | bababe
# City not found.  Skipping...
# Processing Record 4 of Set 6 | carballo
# Processing Record 5 of Set 6 | promyshlennovskiy
# Processing Record 6 of Set 6 | kodiak
# Processing Record 7 of Set 6 | manono
# Processing Record 8 of Set 6 | hofn
# Processing Record 9 of Set 6 | arlit
# Processing Record 10 of Set 6 | luce
# Processing Record 11 of Set 6 | osorno
# Processing Record 12 of Set 6 | sinnamary
# Processing Record 13 of Set 6 | sena madureira
# Processing Record 14 of Set 6 | fallon
# Processing Record 15 of Set 6 | bolivar
# Processing Record 16 of Set 6 | fomboni
# Processing Record 17 of Set 6 | tabas
# Processing Record 18 of Set 6 | lavrentiya
# Processing Record 19 of Set 6 | samarai
# Processing Record 20 of Set 6 | grand river south east
# City not found.  Skipping...
# Processing Record 21 of Set 6 | henties bay
# Processing Record 22 of Set 6 | katangli
# Processing Record 23 of Set 6 | husavik
# Processing Record 24 of Set 6 | nortelandia
# Processing Record 25 of Set 6 | oranjemund
# Processing Record 26 of Set 6 | lashio
# Processing Record 27 of Set 6 | ponta do sol
# Processing Record 28 of Set 6 | presidencia roque saenz pena
# Processing Record 29 of Set 6 | benin
# Processing Record 30 of Set 6 | marsh harbour
# Processing Record 31 of Set 6 | pailon
# Processing Record 32 of Set 6 | east london
# Processing Record 33 of Set 6 | galgani
# City not found.  Skipping...
# Processing Record 34 of Set 6 | pierre-benite
# Processing Record 35 of Set 6 | menzelinsk
# Processing Record 36 of Set 6 | grindavik
# Processing Record 37 of Set 6 | durban
# Processing Record 38 of Set 6 | limbang
# Processing Record 39 of Set 6 | gotsu
# Processing Record 40 of Set 6 | yamada
# Processing Record 41 of Set 6 | guerrero negro
# Processing Record 42 of Set 6 | bonnyville
# Processing Record 43 of Set 6 | nicoya
# Processing Record 44 of Set 6 | havre-saint-pierre
# Processing Record 45 of Set 6 | sinnar
# Processing Record 46 of Set 6 | sentyabrskiy
# City not found.  Skipping...
# Processing Record 47 of Set 6 | rolim de moura
# City not found.  Skipping...
# Processing Record 48 of Set 6 | axim
# Processing Record 49 of Set 6 | bindura
# Processing Record 50 of Set 6 | saint george
# Processing Record 1 of Set 7 | georgetown
# Processing Record 2 of Set 7 | vila velha
# Processing Record 3 of Set 7 | chapais
# Processing Record 4 of Set 7 | yarovoye
# Processing Record 5 of Set 7 | lakes entrance
# Processing Record 6 of Set 7 | sioux lookout
# Processing Record 7 of Set 7 | lazaro cardenas
# Processing Record 8 of Set 7 | campbell river
# Processing Record 9 of Set 7 | gornopravdinsk
# Processing Record 10 of Set 7 | nanortalik
# Processing Record 11 of Set 7 | dutse
# Processing Record 12 of Set 7 | oiso
# Processing Record 13 of Set 7 | plettenberg bay
# Processing Record 14 of Set 7 | saryozek
# Processing Record 15 of Set 7 | shashi
# Processing Record 16 of Set 7 | aleksandrov gay
# Processing Record 17 of Set 7 | pervomaysk
# Processing Record 18 of Set 7 | samara
# Processing Record 19 of Set 7 | bolungarvik
# City not found.  Skipping...
# Processing Record 20 of Set 7 | redmond
# Processing Record 21 of Set 7 | izhma
# Processing Record 22 of Set 7 | tromso
# Processing Record 23 of Set 7 | havelock
# Processing Record 24 of Set 7 | mwene-ditu
# Processing Record 25 of Set 7 | novaya ladoga
# Processing Record 26 of Set 7 | zarate
# Processing Record 27 of Set 7 | sao filipe
# Processing Record 28 of Set 7 | kozhevnikovo
# Processing Record 29 of Set 7 | kyra
# Processing Record 30 of Set 7 | lagoa
# Processing Record 31 of Set 7 | sibolga
# Processing Record 32 of Set 7 | posse
# Processing Record 33 of Set 7 | talcahuano
# Processing Record 34 of Set 7 | kavaratti
# Processing Record 35 of Set 7 | sarangani
# Processing Record 36 of Set 7 | fortuna
# Processing Record 37 of Set 7 | abaete
# Processing Record 38 of Set 7 | svetlogorsk
# Processing Record 39 of Set 7 | haines junction
# Processing Record 40 of Set 7 | tamiahua
# Processing Record 41 of Set 7 | kemijarvi
# Processing Record 42 of Set 7 | cherskiy
# Processing Record 43 of Set 7 | puro
# Processing Record 44 of Set 7 | luwingu
# Processing Record 45 of Set 7 | cabra
# Processing Record 46 of Set 7 | sur
# Processing Record 47 of Set 7 | quang ngai
# Processing Record 48 of Set 7 | bandarbeyla
# Processing Record 49 of Set 7 | liyang
# Processing Record 50 of Set 7 | aklavik
# Processing Record 1 of Set 8 | okato
# Processing Record 2 of Set 8 | pulandian
# Processing Record 3 of Set 8 | horsham
# Processing Record 4 of Set 8 | portland
# Processing Record 5 of Set 8 
# Processing Record 41 of Set 9 | yumen
# Processing Record 42 of Set 9 | tomohon
# Processing Record 43 of Set 9 | bamiantong
# Processing Record 44 of Set 9 | sao felix do xingu
# Processing Record 45 of Set 9 | chongwe
# Processing Record 46 of Set 9 | southbridge
# Processing Record 47 of Set 9 | bitung
# Processing Record 48 of Set 9 | anchorage
# Processing Record 49 of Set 9 | yerofey pavlovich
# Processing Record 50 of Set 9 | buariki
# City not found.  Skipping...
# Processing Record 1 of Set 10 | akaszto
# Processing Record 2 of Set 10 | jasper
# Processing Record 3 of Set 10 | juneau
# Processing Record 4 of Set 10 | bubaque
# Processing Record 5 of Set 10 | dingli
# Processing Record 6 of Set 10 | umzimvubu
# City not found.  Skipping...
# Processing Record 7 of Set 10 | gazanjyk
# Processing Record 8 of Set 10 | celestun
# Processing Record 9 of Set 10 | kurayoshi
# Processing Record 10 of Set 10 | imbituba
# Processing Record 11 of Set 10 | kokkola
# Processing Record 12 of Set 10 | tasbuget
# City not found.  Skipping...
# Processing Record 13 of Set 10 | mount gambier
# Processing Record 14 of Set 10 | mouzakion
# City not found.  Skipping...
# Processing Record 15 of Set 10 | saint-louis
# Processing Record 16 of Set 10 | evensk
# Processing Record 17 of Set 10 | campeche
# Processing Record 18 of Set 10 | ahipara
# Processing Record 19 of Set 10 | karauzyak
# City not found.  Skipping...
# Processing Record 20 of Set 10 | da nang
# Processing Record 21 of Set 10 | talara
# Processing Record 22 of Set 10 | sungaipenuh
# Processing Record 23 of Set 10 | cam ranh
# Processing Record 24 of Set 10 | polyarnyy
# Processing Record 25 of Set 10 | yulara
# Processing Record 26 of Set 10 | bardiyah
# Processing Record 27 of Set 10 | solwezi
# Processing Record 28 of Set 10 | taihe
# Processing Record 29 of Set 10 | mitsamiouli
# Processing Record 30 of Set 10 | ponta delgada
# Processing Record 31 of Set 10 | fiche
# Processing Record 32 of Set 10 | kaabong
# Processing Record 33 of Set 10 | dolores
# Processing Record 34 of Set 10 | tevriz
# Processing Record 35 of Set 10 | tankhoy
# Processing Record 36 of Set 10 | velyka bilozerka
# Processing Record 37 of Set 10 | vilhena
# Processing Record 38 of Set 10 | jalu
# Processing Record 39 of Set 10 | dolbeau
# City not found.  Skipping...
# Processing Record 40 of Set 10 | agadez
# Processing Record 41 of Set 10 | canutama
# Processing Record 42 of Set 10 | gerash
# Processing Record 43 of Set 10 | tyulyachi
# Processing Record 44 of Set 10 | sosnovo-ozerskoye
# Processing Record 45 of Set 10 | santa fe
# Processing Record 46 of Set 10 | salinopolis
# Processing Record 47 of Set 10 | fort nelson
# Processing Record 48 of Set 10 | malakal
# Processing Record 49 of Set 10 | ambatofinandrahana
# Processing Record 50 of Set 10 | coihaique
# Processing Record 1 of Set 11 | saint-pierre
# Processing Record 2 of Set 11 | ust-nera
# Processing Record 3 of Set 11 | bealanana
# Processing Record 4 of Set 11 | anyang
# Processing Record 5 of Set 11 | goderich
# Processing Record 6 of Set 11 | hoquiam
# Processing Record 7 of Set 11 | zhigansk
# Processing Record 8 of Set 11 | saryshagan
# City not found.  Skipping...
# Processing Record 9 of Set 11 | rosetta
# Processing Record 10 of Set 11 | roma
# Processing Record 11 of Set 11 | gambiran
# Processing Record 12 of Set 11 | yatou
# Processing Record 13 of Set 11 | alekseyevsk
# Processing Record 14 of Set 11 | dapaong
# Processing Record 15 of Set 11 | muhos
# Processing Record 16 of Set 11 | sulangan
# Processing Record 17 of Set 11 | karasburg
# Processing Record 18 of Set 11 | hamilton
# Processing Record 19 of Set 11 | gwadar
# Processing Record 20 of Set 11 | matiguas
# Processing Record 21 of Set 11 | lumeje
# Processing Record 22 of Set 11 | poum
# Processing Record 23 of Set 11 | alofi
# Processing Record 24 of Set 11 | tucumcari
# Processing Record 25 of Set 11 | verkhnyaya maksakovka
# Processing Record 26 of Set 11 | kahta
# Processing Record 27 of Set 11 | california city
# Processing Record 28 of Set 11 | anadyr
# Processing Record 29 of Set 11 | grottammare
# Processing Record 30 of Set 11 | shanting
# Processing Record 31 of Set 11 | mehamn
# Processing Record 32 of Set 11 | bure
# Processing Record 33 of Set 11 | kedrovyy
# Processing Record 34 of Set 11 | labutta
# City not found.  Skipping...
# Processing Record 35 of Set 11 | chokwe
# Processing Record 36 of Set 11 | gamba
# Processing Record 37 of Set 11 | lixourion
# Processing Record 38 of Set 11 | les cayes
# Processing Record 39 of Set 11 | annamalainagar
# Processing Record 40 of Set 11 | manggar
# Processing Record 41 of Set 11 | bereda
# Processing Record 42 of Set 11 | luderitz
# Processing Record 43 of Set 11 | burgeo
# Processing Record 44 of Set 11 | vardo
# Processing Record 45 of Set 11 | zhaotong
# Processing Record 46 of Set 11 | aasiaat
# Processing Record 47 of Set 11 | halalo
# City not found.  Skipping...
# Processing Record 48 of Set 11 | bilibino
# Processing Record 49 of Set 11 | khandyga
# Processing Record 50 of Set 11 | banda aceh
# Processing Record 1 of Set 12 | bilma
# Processing Record 2 of Set 12 | litoral del san juan
# City not found.  Skipping...
# Processing Record 3 of Set 12 | el faiyum
# City not found.  Skipping...
# Processing Record 4 of Set 12 | raton
# Processing Record 5 of Set 12 | la ronge
# Processing Record 6 of Set 12 | clonakilty
# Processing Record 7 of Set 12 | segezha
# Processing Record 8 of Set 12 | badami
# Processing Record 9 of Set 12 | poronaysk
# Processing Record 10 of Set 12 | barroso
# Processing Record 11 of Set 12 | finschhafen
# Processing Record 12 of Set 12 | fare
# Processing Record 13 of Set 12 | mantua
# Processing Record 14 of Set 12 | poso
# Processing Record 15 of Set 12 | houma
# Processing Record 16 of Set 12 | santiago del estero
# Processing Record 17 of Set 12 | abadan
# Processing Record 18 of Set 12 | zhangjiakou

# %%
df = pd.DataFrame(data, columns = ['City','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Country','Date'])
df

#City	Lat	Lng	Max Temp	Humidity	Cloudiness	Wind Speed	Country	Date
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           punta arenas -53.1500  -70.9167     42.91        61          75
# 1              caronport  50.4501 -105.8179    -12.32        99          93
# 2                ushuaia -54.8000  -68.3000     40.66        75          20
# 3               olafsvik  64.8945  -23.7142     27.55        74          93
# 4              hithadhoo  -0.6000   73.0833     81.73        74         100
# ..                   ...      ...       ...       ...       ...         ...
# 520                 poso  -1.3959  120.7524     86.99        58          92
# 521                houma  29.5958  -90.7195     46.00        97         100
# 522  santiago del estero -27.7951  -64.2615     76.15        77          55
# 523               abadan  30.3392   48.3043     58.95        88          75
# 524          zhangjiakou  40.8100  114.8794     15.64        40           4
#
#      Wind Speed Country        Date
# 0          6.91      CL  1643948998
# 1          7.14      CA  1643948998
# 2         13.80      AR  1643948999
# 3         25.86      IS  1643948999
# 4         10.11      MV  1643948999
# ..          ...     ...         ...
# 520        4.94      ID  1643949805
# 521       13.22      US  1643949806
# 522        8.59      AR  1643949806
# 523       11.50      IR  1643949806
# 524       11.52      CN  1643949547
#
# [525 rows x 9 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df.to_csv(output_data_file)

# %%
df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  525.000000  525.000000  525.000000  525.000000  525.000000  525.000000
# mean    20.157109   19.620213   47.797352   74.630476   60.820952    8.152857
# std     34.022978   89.519605   31.218125   21.452518   40.653234    6.302717
# min    -54.800000 -175.200000  -45.360000    3.000000    0.000000    0.000000
# 25%     -7.844700  -57.615200   25.000000   64.000000   18.000000    3.440000
# 50%     25.121600   25.570100   54.630000   79.000000   75.000000    6.620000
# 75%     49.216700  100.354300   74.010000   92.000000  100.000000   11.010000
# max     78.218600  179.316700  108.010000  100.000000  100.000000   50.060000
#
#                Date
# count  5.250000e+02
# mean   1.643949e+09
# std    2.529410e+02
# min    1.643949e+09
# 25%    1.643949e+09
# 50%    1.643949e+09
# 75%    1.643950e+09
# max    1.643950e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
df[df['Humidity'] > 100]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# No cities with greater than 100% humidity.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#variables
x = df['Lat']
y = df['Max Temp']

#Plotting
plt.figure(figsize = (12, 8))
plt.scatter(x, y, edgecolor = "black")

#editing
plt.title('Latitude vs Max Temp (%s)' % time.strftime ('%x'), size=14)
plt.xlabel('Latitude', size = 12)
plt.ylabel('Max Temp (F)',  size = 12)
plt.grid(True)
plt.show
plt.savefig("../output_data/fig1.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#variables
x = df['Lat']
y = df['Humidity']

#Plotting
plt.figure(figsize = (12, 8))
plt.scatter(x, y, edgecolor = "black")

#editing
plt.title('Latitude vs Humidity (%s)' % time.strftime ('%x'), size=14)
plt.xlabel('Latitude', size = 12)
plt.ylabel('Humidity',  size = 12)
plt.grid(True)
plt.show
plt.savefig("../output_data/fig2.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#variables
x = df['Lat']
y = df['Cloudiness']

#Plotting
plt.figure(figsize = (12, 8))
plt.scatter(x, y, edgecolor = "black")

#editing
plt.title('Latitude vs Cloudiness (%s)' % time.strftime ('%x'), size=14)
plt.xlabel('Latitude', size = 12)
plt.ylabel('Cloudiness',  size = 12)
plt.grid(True)
plt.show
plt.savefig("../output_data/fig3.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#variables
x = df['Lat']
y = df['Wind Speed']

#Plotting
plt.figure(figsize = (12, 8))
plt.scatter(x, y, edgecolor = "black")

#editing
plt.title('Latitude vs Wind Speed (%s)' % time.strftime ('%x'), size=14)
plt.xlabel('Latitude', size = 12)
plt.ylabel('Wind Speed',  size = 12)
plt.grid(True)
plt.show
plt.savefig("../output_data/fig4.png")

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#variables 
north_hem = df.loc[df["Lat"] > 0]
south_hem = df.loc[df["Lat"] < 0]
x = north_hem['Lat']
y = north_hem['Max Temp']

#Plotting
plt.figure(figsize = (12, 8))
plt.scatter(x, y, edgecolor = "black")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept
print("The r-value is: " + str(rvalue))

plt.plot(x , regress , "r-")
regline = "y = " + str(round(slope , 2)) + "x + " + str(round(intercept , 2))
plt.annotate(regline , (10 , -20) , fontsize = 14 , color = "red")

#Editing
plt.title('Northern Hemisphere Max Temp vs Lat (%s)' % time.strftime ('%x'), size=14)
plt.xlabel('Latitude', size = 12)
plt.ylabel('Max Temperature (F)',  size = 12)
plt.grid(True)
plt.show
plt.savefig("../output_data/fig5.png")
# Out:
# The r-value is: -0.8808489811601528

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#variables 
north_hem = df.loc[df["Lat"] > 0]
south_hem = df.loc[df["Lat"] < 0]
x = south_hem['Lat']
y = south_hem['Max Temp']

#Plotting
plt.figure(figsize = (12, 8))
plt.scatter(x, y, edgecolor = "black")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept
print("The r-value is: " + str(rvalue))

plt.plot(x , regress , "r-")
regline = "y = " + str(round(slope , 2)) + "x + " + str(round(intercept , 2))
plt.annotate(regline , (-50 , 90) , fontsize = 14 , color = "red")

#Editing
plt.title('Southern Hemisphere Max Temp vs Lat (%s)' % time.strftime ('%x'), size=14)
plt.xlabel('Latitude', size = 12)
plt.ylabel('Max Temperature (F)',  size = 12)
plt.grid(True)
plt.show
plt.savefig("../output_data/fig6.png")
# Out:
# The r-value is: 0.5017652593400186

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#variables 
north_hem = df.loc[df["Lat"] > 0]
south_hem = df.loc[df["Lat"] < 0]
x = north_hem['Lat']
y = north_hem['Humidity']

#Plotting
plt.figure(figsize = (12, 8))
plt.scatter(x, y, edgecolor = "black")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept
print("The r-value is: " + str(rvalue))

plt.plot(x , regress , "r-")
regline = "y = " + str(round(slope , 2)) + "x + " + str(round(intercept , 2))
plt.annotate(regline , (50 , 20) , fontsize = 14 , color = "red")

#Editing
plt.title('Northern Hemisphere Humidity vs Lat (%s)' % time.strftime ('%x'), size=14)
plt.xlabel('Latitude', size = 12)
plt.ylabel('Humidity',  size = 12)
plt.grid(True)
plt.show
plt.savefig("../output_data/fig7.png")
# Out:
# The r-value is: 0.40528359597173025

# %% [markdown]
# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#variables 
north_hem = df.loc[df["Lat"] > 0]
south_hem = df.loc[df["Lat"] < 0]
x = south_hem['Lat']
y = south_hem['Humidity']

#Plotting
plt.figure(figsize = (12, 8))
plt.scatter(x, y, edgecolor = "black")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept
print("The r-value is: " + str(rvalue))

plt.plot(x , regress , "r-")
regline = "y = " + str(round(slope , 2)) + "x + " + str(round(intercept , 2))
plt.annotate(regline , (-55 , 65) , fontsize = 14 , color = "red")

#Editing
plt.title('Southern Hemisphere Humidity vs Lat (%s)' % time.strftime ('%x'), size=14)
plt.xlabel('Latitude', size = 12)
plt.ylabel('Humidity',  size = 12)
plt.grid(True)
plt.show
plt.savefig("../output_data/fig8.png")
# Out:
# The r-value is: 0.17269199223758516

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#variables 
north_hem = df.loc[df["Lat"] > 0]
south_hem = df.loc[df["Lat"] < 0]
x = north_hem['Lat']
y = north_hem['Cloudiness']

#Plotting
plt.figure(figsize = (12, 8))
plt.scatter(x, y, edgecolor = "black")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept
print("The r-value is: " + str(rvalue))

plt.plot(x , regress , "r-")
regline = "y = " + str(round(slope , 2)) + "x + " + str(round(intercept , 2))
plt.annotate(regline , (60 , 55) , fontsize = 14 , color = "red")

#Editing
plt.title('Northern Hemisphere Cloudiness vs Lat (%s)' % time.strftime ('%x'), size=14)
plt.xlabel('Latitude', size = 12)
plt.ylabel('Cloudiness',  size = 12)
plt.grid(True)
plt.show
plt.savefig("../output_data/fig9.png")
# Out:
# The r-value is: 0.3534931694143194

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#variables 
north_hem = df.loc[df["Lat"] > 0]
south_hem = df.loc[df["Lat"] < 0]
x = south_hem['Lat']
y = south_hem['Cloudiness']

#Plotting
plt.figure(figsize = (12, 8))
plt.scatter(x, y, edgecolor = "black")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept
print("The r-value is: " + str(rvalue))

plt.plot(x , regress , "r-")
regline = "y = " + str(round(slope , 2)) + "x + " + str(round(intercept , 2))
plt.annotate(regline , (-55 , 60) , fontsize = 14 , color = "red")

#Editing
plt.title('Southern Hemisphere Cloudiness vs Lat (%s)' % time.strftime ('%x'), size=14)
plt.xlabel('Latitude', size = 12)
plt.ylabel('Cloudiness',  size = 12)
plt.grid(True)
plt.show
plt.savefig("../output_data/fig10.png")
# Out:
# The r-value is: 0.17865952355608253

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#variables 
north_hem = df.loc[df["Lat"] > 0]
south_hem = df.loc[df["Lat"] < 0]
x = north_hem['Lat']
y = north_hem['Wind Speed']

#Plotting
plt.figure(figsize = (12, 8))
plt.scatter(x, y, edgecolor = "black")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept
print("The r-value is: " + str(rvalue))

plt.plot(x , regress , "r-")
regline = "y = " + str(round(slope , 2)) + "x + " + str(round(intercept , 2))
plt.annotate(regline , (10 , 30) , fontsize = 14 , color = "red")

#Editing
plt.title('Northern Hemisphere Wind Speed vs Lat (%s)' % time.strftime ('%x'), size=14)
plt.xlabel('Latitude', size = 12)
plt.ylabel('Wind Speed',  size = 12)
plt.grid(True)
plt.show
plt.savefig("../output_data/fig11.png")
# Out:
# The r-value is: 0.08725874477238375

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#variables 
north_hem = df.loc[df["Lat"] > 0]
south_hem = df.loc[df["Lat"] < 0]
x = south_hem['Lat']
y = south_hem['Wind Speed']

#Plotting
plt.figure(figsize = (12, 8))
plt.scatter(x, y, edgecolor = "black")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept
print("The r-value is: " + str(rvalue))

plt.plot(x , regress , "r-")
regline = "y = " + str(round(slope , 2)) + "x + " + str(round(intercept , 2))
plt.annotate(regline , (-55 , 20) , fontsize = 14 , color = "red")

#Editing
plt.title('Southern Hemisphere Wind Speed vs Lat (%s)' % time.strftime ('%x'), size=14)
plt.xlabel('Latitude', size = 12)
plt.ylabel('Wind Speed',  size = 12)
plt.grid(True)
plt.show
plt.savefig("../output_data/fig12.png")
# Out:
# The r-value is: -0.13025183493974915
